# %%
import importlib
import abusedbtest as connector
importlib.reload(connector.config)
# Out:
# <module 'abusedbtest.config' from '/Users/admin/NOSYNC/cog-integrations/abusedbtest/config.py'>

# %%
connector.test.print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/mm/rm6x0bmn5lx9d2616k4fnkvc0000gn/T/ipykernel_78297/2234191582.py in <module>
# ----> 1 connector.test.print()
#
# AttributeError: module 'abusedbtest.test' has no attribute 'print'

# %%
connector.config.yaml2dict()
# Out:
# {'categories': ['Data Enrichment', 'Threat Intelligence'],
#  'common': {'id': 'AbuseIPDB',
#   'version': 1.0,
#   'description': 'Central repository to report and identify IP addresses that have been associated with malicious activity online. Check the Detailed Information section for more information on how to configure the integration.',
#   'display': 'AbuseIPDB'},
#  'configuration': [{'defaultvalue': 'https://api.abuseipdb.com/api/v2/',
#    'display': 'AbuseIP server URL',
#    'name': 'server',
#    'required': True,
#    'type': 'string'},
#   {'display': 'API Key (v2)', 'name': 'apikey', 'type': 'password'},
#   {'display': 'Minimum score threshold',
#    'name': 'threshold',
#    'type': 'integer',
#    'defaultvalue': 80},
#   {'display': 'Maximum reports age (in days)',
#    'name': 'days',
#    'type': 'integer',
#    'defaultvalue': 30},
#   {'display': 'Disregard quota errors',
#    'name': 'disregard_quota',
#    'type': 'bool',
#    'defaultvalue': False},
# ...
